# %% [markdown]
# ### 作業目的: 了解為何需要推論方法的詞向量及其優缺點
# 本次作業主要為思考題，請學員根據題目思考適合的回答

# %% [markdown]
# ### Question:
# 本次課程學習了word2vec中的兩個模型CBOW與Skip-gram，請學員思考與比較此兩種模型的優缺點?

# %% [markdown]
# ### Answer:
#
# * **CBOW**:
#
# ###相對於 skip-gram, CBOW 訓練速度較快。###
#
# * **Skip-gram**:
#
# ###以中心詞預測周圍的詞，同樣的中心詞會與多個周圍的詞配對，也使較少出現的詞 skip-gram 的表現相對於 CBOW 較優###
